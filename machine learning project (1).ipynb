# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\kumma\Downloads\Well production analysis data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df=pd.read_csv(r'C:\Users\kumma\Downloads\Well production analysis data.csv')
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
try:
    df = pd.read_csv('Well production analysis data.csv')
    print(df.head())
except PermissionError:
    print("Permission denied. Please check the file permissions or if the file is open elsewhere.")
# Out:
# Permission denied. Please check the file permissions or if the file is open elsewhere.

# %%
chmod 644 'Well production analysis data.csv'  # Read permission
chmod 755 'Well production analysis data.csv'  # Read/Write/Execute for owner, read/execute for others
# Out:
#   Cell In[14], line 1
#     chmod 644 'Well production analysis data.csv'  # Read permission
#           ^
# SyntaxError: invalid syntax

# %%
df = pd.read_excel('Downloads/Book1 vinay project(machine learning).xlsx')
df
# Out:
#          DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0     2014-04-07         15/9-F-1 C            0.0                  0.000
# 1     2014-04-08         15/9-F-1 C            0.0                    NaN
# 2     2014-04-09         15/9-F-1 C            0.0                    NaN
# 3     2014-04-10         15/9-F-1 C            0.0                    NaN
# 4     2014-04-11         15/9-F-1 C            0.0                310.376
# ...          ...                ...            ...                    ...
# 15629 2016-09-14           15/9-F-5            0.0                    NaN
# 15630 2016-09-15           15/9-F-5            0.0                    NaN
# 15631 2016-09-16           15/9-F-5            0.0                    NaN
# 15632 2016-09-17           15/9-F-5            0.0                    NaN
# 15633 2016-09-18           15/9-F-5            0.0                    NaN
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   15634 non-null  datetime64[ns]
#  1   NPD_WELL_BORE_NAME        15634 non-null  object
#  2   ON_STREAM_HRS             15349 non-null  float64
#  3   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  5   AVG_DP_TUBING             8980 non-null   float64
#  6   AVG_ANNULUS_PRESS         7890 non-null   float64
#  7   AVG_CHOKE_SIZE_P          8919 non-null   float64
#  8   AVG_WHP_P                 9155 non-null   float64
#  9   AVG_WHT_P                 9146 non-null   float64
#  10  DP_CHOKE_SIZE             15340 non-null  float64
#  11  BORE_OIL_VOL              9161 non-null   float64
#  12  BORE_GAS_VOL              9161 non-null   float64
# ...

# %%
df1=df.loc[0:9000]
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9001 entries, 0 to 9000
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   9001 non-null   datetime64[ns]
#  1   NPD_WELL_BORE_NAME        9001 non-null   object
#  2   ON_STREAM_HRS             9001 non-null   float64
#  3   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  5   AVG_DP_TUBING             8980 non-null   float64
#  6   AVG_ANNULUS_PRESS         7730 non-null   float64
#  7   AVG_CHOKE_SIZE_P          8759 non-null   float64
#  8   AVG_WHP_P                 8995 non-null   float64
#  9   AVG_WHT_P                 8995 non-null   float64
#  10  DP_CHOKE_SIZE             8995 non-null   float64
#  11  BORE_OIL_VOL              9001 non-null   float64
#  12  BORE_GAS_VOL              9001 non-null   float64
# ...

# %%
[df1.isnull()]
# Out:
# [      DATEPRD  NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
#  0       False               False          False                  False
#  1       False               False          False                   True
#  2       False               False          False                   True
#  3       False               False          False                   True
#  4       False               False          False                  False
#  ...       ...                 ...            ...                    ...
#  8996    False               False          False                  False
#  8997    False               False          False                  False
#  8998    False               False          False                  False
#  8999    False               False          False                  False
#  9000    False               False          False                  False
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# ...

# %%
df2=df1.dropna(how='all')
df2.info()
df2.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9001 entries, 0 to 9000
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   9001 non-null   datetime64[ns]
#  1   NPD_WELL_BORE_NAME        9001 non-null   object
#  2   ON_STREAM_HRS             9001 non-null   float64
#  3   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  5   AVG_DP_TUBING             8980 non-null   float64
#  6   AVG_ANNULUS_PRESS         7730 non-null   float64
#  7   AVG_CHOKE_SIZE_P          8759 non-null   float64
#  8   AVG_WHP_P                 8995 non-null   float64
#  9   AVG_WHT_P                 8995 non-null   float64
#  10  DP_CHOKE_SIZE             8995 non-null   float64
#  11  BORE_OIL_VOL              9001 non-null   float64
#  12  BORE_GAS_VOL              9001 non-null   float64
# ...

# %%
df3=df2[['DATEPRD','AVG_DOWNHOLE_PRESSURE','AVG_DOWNHOLE_TEMPERATURE','AVG_DP_TUBING','AVG_CHOKE_SIZE_P','BORE_OIL_VOL','BORE_GAS_VOL','BORE_WAT_VOL']]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9001 entries, 0 to 9000
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   9001 non-null   datetime64[ns]
#  1   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  2   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  3   AVG_DP_TUBING             8980 non-null   float64
#  4   AVG_CHOKE_SIZE_P          8759 non-null   float64
#  5   BORE_OIL_VOL              9001 non-null   float64
#  6   BORE_GAS_VOL              9001 non-null   float64
#  7   BORE_WAT_VOL              9001 non-null   float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 562.7 KB

# %%
df4=df3.dropna()
df4=df4.rename(columns={'DATEPRD':'date','AVG_DOWNHOLE_PRESSURE':'avg_pre','AVG_DOWNHOLE_TEMPERATURE':'avg_temp','AVG_DP_TUBING':'avg_tubing','AVG_CHOKE_SIZE_P':'avg_chokesize','BORE_OIL_VOL':'oil_vol','BORE_GAS_VOL':'gas_vol','BORE_WAT_VOL':'water_vol'})
df4
df4 = df4[~((df4['gas_vol'] == 0) & (df4['oil_vol'] == 0))]
df4[(df4['avg_pre'] == 0) & (df4['avg_temp'] == 0)] 
mean_avg_pre = df4['avg_pre'].mean()
mean_avg_temp = df4['avg_temp'].mean()

df4.loc[(df4['avg_pre'] == 0) & (df4['avg_temp'] == 0), ['avg_pre', 'avg_temp']] = [mean_avg_pre, mean_avg_temp]
df4[(df4['avg_pre'] == 0) & (df4['avg_temp'] == 0)]
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7867 entries, 15 to 8927
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           7867 non-null   datetime64[ns]
#  1   avg_pre        7867 non-null   float64
#  2   avg_temp       7867 non-null   float64
#  3   avg_tubing     7867 non-null   float64
#  4   avg_chokesize  7867 non-null   float64
#  5   oil_vol        7867 non-null   float64
#  6   gas_vol        7867 non-null   float64
#  7   water_vol      7867 non-null   float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 553.1 KB

# %%
df4[(df4['avg_pre'] == 0) & (df4['avg_temp'] == 0)]
# Out:
# Empty DataFrame
# Columns: [date, avg_pre, avg_temp, avg_tubing, avg_chokesize, oil_vol, gas_vol, water_vol]
# Index: []

# %%
has_zero_values = (df4 == 0).any().any()

print("The DataFrame has zero values:", has_zero_values)
# Out:
# The DataFrame has zero values: True

# %%
df4[(df4['avg_tubing'] == 0)]
# Out:
#           date     avg_pre   avg_temp  avg_tubing  avg_chokesize  oil_vol  \
# 766 2013-07-28  181.571381  78.947726         0.0        2.46422     56.0
# 767 2013-07-29  181.571381  78.947726         0.0        2.53699    124.0
#
#      gas_vol  water_vol
# 766   9012.0        0.0
# 767  18793.0        0.0

# %%
df4 = df4[df4['avg_tubing'] != 0]
df4[(df4['water_vol'] == 0)]
# Out:
#            date  avg_pre  avg_temp  avg_tubing  avg_chokesize  oil_vol  \
# 15   2014-04-22  289.421   106.353     182.059       43.34345    631.0
# 16   2014-04-23  270.240   107.644     171.053       47.16752   1166.0
# 17   2014-04-24  262.843   107.869     168.242       47.73231   1550.0
# 18   2014-04-25  255.527   107.971     165.539       48.53377   1249.0
# 19   2014-04-26  247.199   108.052     162.422       49.84450   1346.0
# ...         ...      ...       ...         ...            ...      ...
# 8280 2014-09-28  199.514   106.678     158.587       11.41419    195.0
# 8281 2014-09-29  201.767   106.668     162.095        3.04923     11.0
# 8282 2014-09-30  215.242   105.700     164.749        7.25661    114.0
# 8601 2015-08-15  281.853   104.071     189.179        1.65052     58.0
# 8836 2016-04-06  257.815   103.309     187.442        1.10443      0.0
#
#        gas_vol  water_vol
# 15     90439.0        0.0
# 16    165720.0        0.0
# 17    221707.0        0.0
# ...

# %%
df4.index = range(1, len(df4) + 1)
df4.to_excel('machinelearningcleaneddata_output.xlsx', index=False)

# %%
df5=df4.loc[1:6000]
df6=df4.loc[6001:7865]

# %%
df5
# Out:
#            date  avg_pre  avg_temp  avg_tubing  avg_chokesize  oil_vol  \
# 1    2014-04-22  289.421   106.353     182.059       43.34345    631.0
# 2    2014-04-23  270.240   107.644     171.053       47.16752   1166.0
# 3    2014-04-24  262.843   107.869     168.242       47.73231   1550.0
# 4    2014-04-25  255.527   107.971     165.539       48.53377   1249.0
# 5    2014-04-26  247.199   108.052     162.422       49.84450   1346.0
# ...         ...      ...       ...         ...            ...      ...
# 5996 2013-06-15  244.763   100.798     212.545      100.00000    852.0
# 5997 2013-06-16  244.659   100.795     212.486      100.00000    861.0
# 5998 2013-06-17  244.811   100.790     212.585      100.00000    877.0
# 5999 2013-06-18  244.700   100.781     212.597      100.00000    878.0
# 6000 2013-06-19  244.596   100.770     212.501      100.00000    879.0
#
#        gas_vol  water_vol
# 1      90439.0        0.0
# 2     165720.0        0.0
# 3     221707.0        0.0
# ...

# %%
df6
# Out:
#            date  avg_pre  avg_temp  avg_tubing  avg_chokesize  oil_vol  \
# 6001 2013-06-20  244.728   100.769     212.631      100.00000    876.0
# 6002 2013-06-21  245.403   100.773     213.365      100.00000    788.0
# 6003 2013-06-22  251.893   100.677     216.344       75.49431    421.0
# 6004 2013-06-23  248.803   100.771     217.708       14.44986     76.0
# 6005 2013-06-26  249.586   100.708     213.820       64.95720    696.0
# ...         ...      ...       ...         ...            ...      ...
# 7861 2016-06-30  196.611   106.498     179.793       28.26319    144.0
# 7862 2016-07-01  193.302   106.539     177.447       31.05844    146.0
# 7863 2016-07-02  194.984   106.518     179.171       31.57577    144.0
# 7864 2016-07-03  194.978   106.516     179.204       31.54061    145.0
# 7865 2016-07-04  194.317   106.521     178.615       31.52210    143.0
#
#        gas_vol  water_vol
# 6001  139009.0     3555.0
# 6002  125102.0     3192.0
# 6003   60352.0     1115.0
# ...

# %%
X=df5[['avg_pre','avg_temp','avg_tubing','avg_chokesize']]
y=df5[['oil_vol','gas_vol','water_vol']]
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=16)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
multi_output = MultiOutputRegressor(model)
multi_output.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=LinearRegression())

# %%
y_pred=multi_output.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score,r2_score

# %%
val=np.sqrt(mean_squared_error(y_test,y_pred))
val
mean_absolute_error(y_test,y_pred,multioutput='raw_values')
# Out:
# array([   863.91461073, 122104.28645998,    931.64140246])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.38045731768645047

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
model1=SVR()
multi_output_clf = MultiOutputRegressor(model1)

multi_output_clf.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=SVR())

# %%
y_pred1=multi_output_clf.predict(X_test)

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.11473975020819949

# %%
val=np.sqrt(mean_squared_error(y_test,y_pred1,multioutput='raw_values'))
val
mean_absolute_error(y_test,y_pred1,multioutput='raw_values')
# Out:
# array([   841.62385649, 141524.043513  ,   1237.09764484])

# %%
from sklearn.ensemble import RandomForestRegressor
model2=RandomForestRegressor()
multi_output_clf1 = MultiOutputRegressor(model2)

multi_output_clf1.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor())

# %%
y_pred2=multi_output_clf1.predict(X_test)

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.954674022541035

# %%
mean_absolute_error(y_test,y_pred2,multioutput='raw_values')
# Out:
# array([  116.55677295, 17563.54362383,   148.01227687])

# %%
importances = [regressor.feature_importances_ for regressor in multi_output_clf1.estimators_]

# Convert to DataFrame for better readability
importance_df = pd.DataFrame(importances, columns=X.columns, index=[f'Target {i+1}' for i in range(len(importances))])
print(importance_df)
# Out:
#            avg_pre  avg_temp  avg_tubing  avg_chokesize
# Target 1  0.043349  0.463989    0.260061       0.232602
# Target 2  0.057147  0.449177    0.264967       0.228709
# Target 3  0.031284  0.206247    0.297535       0.464935

# %%
average_importance = importance_df.mean(axis=0)
print("Average Feature Importance:\n", average_importance)
plt.figure(figsize=(10, 6))
average_importance.sort_values().plot(kind='barh')
plt.title('Average Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
# Out:
# Average Feature Importance:
#  avg_pre          0.043926
# avg_temp         0.373138
# avg_tubing       0.274187
# avg_chokesize    0.308749
# dtype: float64

# %%
from sklearn.ensemble import GradientBoostingRegressor
model3=GradientBoostingRegressor()
multi_output_clf2 = MultiOutputRegressor(model3)

multi_output_clf2.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor())

# %%
y_pred3=multi_output_clf2.predict(X_test)

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.9150346598063086

# %%
mean_absolute_error(y_test,y_pred3,multioutput='raw_values')
# Out:
# array([  259.71230758, 37844.04491861,   266.39938313])

# %%
importances = [regressor.feature_importances_ for regressor in multi_output_clf2.estimators_]

# Convert to DataFrame for better readability
importance_df = pd.DataFrame(importances, columns=X.columns, index=[f'Target {i+1}' for i in range(len(importances))])
print(importance_df)
# Out:
#            avg_pre  avg_temp  avg_tubing  avg_chokesize
# Target 1  0.053145  0.403758    0.192671       0.350426
# Target 2  0.062508  0.395708    0.187413       0.354371
# Target 3  0.025924  0.187286    0.354348       0.432442

# %%
average_importance = importance_df.mean(axis=0)
print("Average Feature Importance:\n", average_importance)
plt.figure(figsize=(10, 6))
average_importance.sort_values().plot(kind='barh')
plt.title('Average Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
# Out:
# Average Feature Importance:
#  avg_pre          0.047193
# avg_temp         0.328917
# avg_tubing       0.244811
# avg_chokesize    0.379079
# dtype: float64

# %%
df6
# Out:
#            date  avg_pre  avg_temp  avg_tubing  avg_chokesize  oil_vol  \
# 6001 2013-06-20  244.728   100.769     212.631      100.00000    876.0
# 6002 2013-06-21  245.403   100.773     213.365      100.00000    788.0
# 6003 2013-06-22  251.893   100.677     216.344       75.49431    421.0
# 6004 2013-06-23  248.803   100.771     217.708       14.44986     76.0
# 6005 2013-06-26  249.586   100.708     213.820       64.95720    696.0
# ...         ...      ...       ...         ...            ...      ...
# 7861 2016-06-30  196.611   106.498     179.793       28.26319    144.0
# 7862 2016-07-01  193.302   106.539     177.447       31.05844    146.0
# 7863 2016-07-02  194.984   106.518     179.171       31.57577    144.0
# 7864 2016-07-03  194.978   106.516     179.204       31.54061    145.0
# 7865 2016-07-04  194.317   106.521     178.615       31.52210    143.0
#
#        gas_vol  water_vol
# 6001  139009.0     3555.0
# 6002  125102.0     3192.0
# 6003   60352.0     1115.0
# ...

# %%
V=df6[['avg_pre','avg_temp','avg_tubing','avg_chokesize']]
y_actual=df6[['oil_vol','gas_vol','water_vol']]

# %%
y_pred4=multi_output_clf1.predict(V)
y_pred4
# Out:
# C:\Users\kumma\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\kumma\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\kumma\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# array([[  128.6 , 23155.06,  2965.19],
#        [  128.6 , 23155.06,  2965.19],
#        [  128.6 , 23155.06,  2965.19],
#        ...,
#        [  128.6 , 23155.06,  2965.19],
#        [  128.6 , 23155.06,  2965.19],
#        [  128.6 , 23155.06,  2965.19]])

# %%
plt.figure(figsize=(12, 6))
plt.plot(df6['date'], y_actual, marker='o', label='Actual Values', color='blue')
plt.plot(df6['date'], y_pred4, marker='x', label='Predicted Values', color='orange')
plt.title('Actual vs Predicted Values Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()  # Adjust layout to fit labels
plt.show()
